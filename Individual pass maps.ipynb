# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import Pitch,Sbopen
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display

# %%
#pip install highlight-text
# Out:
# Requirement already satisfied: highlight-text in c:\users\sauga\anaconda3\lib\site-packages (0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install cmasher
# Out:
# Collecting cmasher
#   Downloading cmasher-1.8.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting colorspacious>=1.1.0 (from cmasher)
#   Downloading colorspacious-1.1.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\sauga\anaconda3\lib\site-packages (from cmasher) (3.8.0)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\sauga\anaconda3\lib\site-packages (from cmasher) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sauga\anaconda3\lib\site-packages (from matplotlib>=3.5->cmasher) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sauga\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->cmasher) (1.16.0)
# Downloading cmasher-1.8.0-py3-none-any.whl (533 kB)
#    ---------------------------------------- 0.0/533.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/533.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/533.3 kB ? eta -:--:--
#    - -------------------------------------- 20.5/533.3 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/533.3 kB 487.6 kB/s eta 0:00:02
#    ---- ---------------------------------- 61.4/533.3 kB 544.7 kB/s eta 0:00:01
#    ----------------- ---------------------- 235.5/533.3 kB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 358.4/533.3 kB 1.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 378.9/533.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  532.5/533.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 533.3/533.3 kB 1.0 MB/s eta 0:00:00
# Downloading colorspacious-1.1.2-py2.py3-none-any.whl (37 kB)
# Installing collected packages: colorspacious, cmasher
# Successfully installed cmasher-1.8.0 colorspacious-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib.request import urlopen
import warnings

import cmasher as cmr
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from highlight_text import ax_text

from mplsoccer import Pitch, VerticalPitch, add_image, FontManager, Sbopen

# %%
comps = sb.competitions()
comps['competition_name'].unique()
# Out:
# array(['1. Bundesliga', 'African Cup of Nations', 'Champions League',
#        'Copa del Rey', "FA Women's Super League", 'FIFA U20 World Cup',
#        'FIFA World Cup', 'Indian Super league', 'La Liga',
#        'Liga Profesional', 'Ligue 1', 'Major League Soccer',
#        'North American League', 'NWSL', 'Premier League', 'Serie A',
#        'UEFA Euro', 'UEFA Europa League', "UEFA Women's Euro",
#        "Women's World Cup"], dtype=object)

# %%
comps[comps['competition_name']=='UEFA Euro']
# Out:
#     competition_id  season_id country_name competition_name  \
# 66              55         43       Europe        UEFA Euro
#
#    competition_gender  competition_youth  competition_international  \
# 66               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 66        2020  2023-02-24T21:26:47.128979  2023-04-27T22:38:34.970148
#
#            match_available_360             match_available
# 66  2023-04-27T22:38:34.970148  2023-02-24T21:26:47.128979

# %%
matches = sb.matches(competition_id=55, season_id=43)
matches[matches['home_team']=='Italy']
# Out:
#     match_id  match_date      kick_off         competition season home_team  \
# 2    3788766  2021-06-20  18:00:00.000  Europe - UEFA Euro   2020     Italy
# 3    3795220  2021-07-06  21:00:00.000  Europe - UEFA Euro   2020     Italy
# 8    3788754  2021-06-16  21:00:00.000  Europe - UEFA Euro   2020     Italy
# 16   3795506  2021-07-11  21:00:00.000  Europe - UEFA Euro   2020     Italy
# 21   3794685  2021-06-26  21:00:00.000  Europe - UEFA Euro   2020     Italy
#
#       away_team  home_score  away_score match_status  ...  \
# 2         Wales           1           0    available  ...
# 3         Spain           1           1    available  ...
# 8   Switzerland           3           0    available  ...
# 16      England           1           1    available  ...
# 21      Austria           2           1    available  ...
#
#               last_updated_360 match_week competition_stage           stadium  \
# 2   2023-04-27T22:22:42.769375          3       Group Stage  Estadio Olímpico
# 3             2022-08-04T12:00          6       Semi-finals   Wembley Stadium
# 8   2023-04-27T22:33:19.992088          2       Group Stage  Estadio Olímpico
# 16            2022-08-04T12:00          7             Final   Wembley Stadium
# 21  2023-04-27T22:07:23.951045          4       Round of 16   Wembley Stadium
#
#                 referee    home_managers                 away_managers  \
# 2   Ovidiu Alin Hațegan  Roberto Mancini                   Robert Page
# 3           Felix Brych  Roberto Mancini  Luis Enrique Martínez García
# 8        Sergey Karasev  Roberto Mancini             Vladimir Petković
# 16        Björn Kuipers  Roberto Mancini              Gareth Southgate
# 21       Anthony Taylor  Roberto Mancini                   Franco Foda
#
#    data_version shot_fidelity_version xy_fidelity_version
# 2         1.1.0                     2                   2
# 3         1.1.0                     2                   2
# 8         1.1.0                     2                   2
# 16        1.1.0                     2                   2
# 21        1.1.0                     2                   2
#
# [5 rows x 22 columns]

# %%
event = sb.events(match_id =3795220)
event
#list(event)
# Out:
#      ball_receipt_outcome ball_recovery_recovery_failure block_offensive  \
# 0                     NaN                            NaN             NaN
# 1                     NaN                            NaN             NaN
# 2                     NaN                            NaN             NaN
# 3                     NaN                            NaN             NaN
# 4                     NaN                            NaN             NaN
# ...                   ...                            ...             ...
# 4822                  NaN                            NaN             NaN
# 4823                  NaN                            NaN             NaN
# 4824                  NaN                            NaN             NaN
# 4825                  NaN                            NaN             NaN
# 4826                  NaN                            NaN             NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  \
# 0                   NaN                  NaN                 NaN
# 1                   NaN                  NaN                 NaN
# 2                   NaN                  NaN                 NaN
# 3                   NaN                  NaN                 NaN
# 4                   NaN                  NaN                 NaN
# ...                 ...                  ...                 ...
# 4822                NaN                  NaN                 NaN
# 4823                NaN                  NaN                 NaN
# 4824                NaN                  NaN                 NaN
# 4825                NaN                  NaN                 NaN
# 4826                NaN                  NaN                 NaN
#
#      clearance_head clearance_left_foot clearance_right_foot counterpress  \
# 0               NaN                 NaN                  NaN          NaN
# 1               NaN                 NaN                  NaN          NaN
# 2               NaN                 NaN                  NaN          NaN
# 3               NaN                 NaN                  NaN          NaN
# 4               NaN                 NaN                  NaN          NaN
# ...             ...                 ...                  ...          ...
# 4822            NaN                 NaN                  NaN          NaN
# 4823            NaN                 NaN                  NaN          NaN
# 4824            NaN                 NaN                  NaN          NaN
# 4825            NaN                 NaN                  NaN          NaN
# 4826            NaN                 NaN                  NaN          NaN
#
#       ... substitution_outcome substitution_outcome_id  \
# 0     ...                  NaN                     NaN
# 1     ...                  NaN                     NaN
# 2     ...                  NaN                     NaN
# 3     ...                  NaN                     NaN
# 4     ...                  NaN                     NaN
# ...   ...                  ...                     ...
# 4822  ...                  NaN                     NaN
# 4823  ...                  NaN                     NaN
# 4824  ...                  NaN                     NaN
# 4825  ...                  NaN                     NaN
# 4826  ...                  NaN                     NaN
#
#      substitution_replacement substitution_replacement_id  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# ...                       ...                         ...
# 4822                      NaN                         NaN
# 4823                      NaN                         NaN
# 4824                      NaN                         NaN
# 4825                      NaN                         NaN
# 4826                      NaN                         NaN
#
#                                                 tactics   team team_id  \
# 0     {'formation': 433, 'lineup': [{'player': {'id'...  Italy     914
# 1     {'formation': 433, 'lineup': [{'player': {'id'...  Spain     772
# 2                                                   NaN  Spain     772
# 3                                                   NaN  Italy     914
# 4                                                   NaN  Spain     772
# ...                                                 ...    ...     ...
# 4822  {'formation': 433, 'lineup': [{'player': {'id'...  Italy     914
# 4823  {'formation': 433, 'lineup': [{'player': {'id'...  Spain     772
# 4824                                                NaN  Italy     914
# 4825                                                NaN  Italy     914
# 4826                                                NaN  Italy     914
#
#          timestamp            type under_pressure
# 0     00:00:00.000     Starting XI            NaN
# 1     00:00:00.000     Starting XI            NaN
# 2     00:00:00.000      Half Start            NaN
# 3     00:00:00.000      Half Start            NaN
# 4     00:00:00.000      Half Start            NaN
# ...            ...             ...            ...
# 4822  00:40:17.205  Tactical Shift            NaN
# 4823  00:03:43.038  Tactical Shift            NaN
# 4824  00:27:22.482           Error            NaN
# 4825  00:11:21.792           Error            NaN
# 4826  00:14:49.568           Error            NaN
#
# [4827 rows x 88 columns]

# %%
parser = Sbopen()
events,related,freeze, tactics = parser.event(3795220)
lineup = parser.lineup(3795220)
lineup
# Out:
#     player_id                     player_name        player_nickname  \
# 0        3166                  Marco Verratti         Marco Verratti
# 1        4355     Emerson Palmieri dos Santos                Emerson
# 2        6954               Giorgio Chiellini      Giorgio Chiellini
# 3        6957                      Alex Meret             Alex Meret
# 4        6964             Alessandro Florenzi    Alessandro Florenzi
# 5        6993                 Bryan Cristante        Bryan Cristante
# 6        7002                    Rafael Tolói           Rafael Tolói
# 7        7024         Jorge Luiz Frello Filho               Jorginho
# 8        7036            Gianluigi Donnarumma   Gianluigi Donnarumma
# 9        7037                 Lorenzo Insigne        Lorenzo Insigne
# 10       7038                Manuel Locatelli       Manuel Locatelli
# 11       7119                Francesco Acerbi       Francesco Acerbi
# 12       7131                Domenico Berardi       Domenico Berardi
# 13       7156                 Federico Chiesa        Federico Chiesa
# 14       7173                Leonardo Bonucci       Leonardo Bonucci
# 15       7469                Salvatore Sirigu       Salvatore Sirigu
# 16       7471                  Andrea Belotti         Andrea Belotti
# 17       7480              Alessandro Bastoni     Alessandro Bastoni
# 18       7777           Federico Bernardeschi  Federico Bernardeschi
# 19       7788                   Ciro Immobile          Ciro Immobile
# 20       8181                  Nicolò Barella         Nicolò Barella
# 21      11514             Giovanni Di Lorenzo    Giovanni Di Lorenzo
# 22      11601                  Matteo Pessina         Matteo Pessina
# 23       3333           David de Gea Quintana           David de Gea
# 24       3477      Álvaro Borja Morata Martín          Álvaro Morata
# 25       3957         César Azpilicueta Tanco      César Azpilicueta
# 26       4353                 Aymeric Laporte        Aymeric Laporte
# 27       5199      Jorge Resurrección Merodio                   Koke
# 28       5203        Sergio Busquets i Burgos        Sergio Busquets
# 29       5208  Thiago Alcântara do Nascimento       Thiago Alcântara
# 30       5211                Jordi Alba Ramos             Jordi Alba
# 31       6596             José Luis Gayà Peña              José Gayá
# 32       6655                Fabián Ruiz Peña            Fabián Ruiz
# 33       6685          Mikel Oyarzabal Ugarte        Mikel Oyarzabal
# 34       6713      Diego Javier Llorente Ríos         Diego Llorente
# 35       6748            Ferrán Torres García          Ferrán Torres
# 36       6765      Rodrigo Hernández Cascante                  Rodri
# 37       6766         Gerard Moreno Balaguero          Gerard Moreno
# 38       6840          Marcos Llorente Moreno        Marcos Llorente
# 39       6892            Pau Francisco Torres             Pau Torres
# 40       9843            Robert Lynch Sanchez         Robert Sanchez
# 41      11333             Adama Traoré Diarra           Adama Traoré
# 42      11748             Unai Simón Mendibil             Unai Simón
# 43      16532            Daniel Olmo Carvajal            Daniel Olmo
# 44      30486            Pedro González López                  Pedri
# 45      31953             Eric García Martret            Eric García
#
#     jersey_number  match_id  team_id team_name  country_id country_name
# 0               6   3795220      914     Italy         112        Italy
# 1              13   3795220      914     Italy         112        Italy
# 2               3   3795220      914     Italy         112        Italy
# 3              26   3795220      914     Italy         112        Italy
# 4              24   3795220      914     Italy         112        Italy
# 5              16   3795220      914     Italy         112        Italy
# 6              25   3795220      914     Italy         112        Italy
# 7               8   3795220      914     Italy         112        Italy
# 8              21   3795220      914     Italy         112        Italy
# 9              10   3795220      914     Italy         112        Italy
# 10              5   3795220      914     Italy         112        Italy
# 11             15   3795220      914     Italy         112        Italy
# 12             11   3795220      914     Italy         112        Italy
# 13             14   3795220      914     Italy         112        Italy
# 14             19   3795220      914     Italy         112        Italy
# 15              1   3795220      914     Italy         112        Italy
# 16              9   3795220      914     Italy         112        Italy
# 17             23   3795220      914     Italy         112        Italy
# 18             20   3795220      914     Italy         112        Italy
# 19             17   3795220      914     Italy         112        Italy
# 20             18   3795220      914     Italy         112        Italy
# 21              2   3795220      914     Italy         112        Italy
# 22             12   3795220      914     Italy         112        Italy
# 23              1   3795220      772     Spain         214        Spain
# 24              7   3795220      772     Spain         214        Spain
# 25              2   3795220      772     Spain         214        Spain
# 26             24   3795220      772     Spain         214        Spain
# 27              8   3795220      772     Spain         214        Spain
# 28              5   3795220      772     Spain         214        Spain
# 29             10   3795220      772     Spain         214        Spain
# 30             18   3795220      772     Spain         214        Spain
# 31             14   3795220      772     Spain         214        Spain
# 32             17   3795220      772     Spain         214        Spain
# 33             21   3795220      772     Spain         214        Spain
# 34              3   3795220      772     Spain         214        Spain
# 35             11   3795220      772     Spain         214        Spain
# 36             16   3795220      772     Spain         214        Spain
# 37              9   3795220      772     Spain         214        Spain
# 38              6   3795220      772     Spain         214        Spain
# 39              4   3795220      772     Spain         214        Spain
# 40             13   3795220      772     Spain         214        Spain
# 41             20   3795220      772     Spain         214        Spain
# 42             23   3795220      772     Spain         214        Spain
# 43             19   3795220      772     Spain         214        Spain
# 44             26   3795220      772     Spain         214        Spain
# 45             12   3795220      772     Spain         214        Spain

# %%
# df with player_id and subbed off time
time_off = events.loc[(events.type_name == 'Substitution'),
                      ['player_id', 'minute']]
time_off.rename({'minute': 'off'}, axis='columns', inplace=True)
# df with player_id and subbed on time
time_on = events.loc[(events.type_name == 'Substitution'),
                     ['substitution_replacement_id', 'minute']]
time_on.rename({'substitution_replacement_id': 'player_id',
                'minute': 'on'}, axis='columns', inplace=True)
players_on = time_on.player_id
# merge on times subbed on/off
lineup = lineup.merge(time_on, on='player_id', how='left')
lineup = lineup.merge(time_off, on='player_id', how='left')
lineup
# Out:
#     player_id                     player_name        player_nickname  \
# 0        3166                  Marco Verratti         Marco Verratti
# 1        4355     Emerson Palmieri dos Santos                Emerson
# 2        6954               Giorgio Chiellini      Giorgio Chiellini
# 3        6957                      Alex Meret             Alex Meret
# 4        6964             Alessandro Florenzi    Alessandro Florenzi
# 5        6993                 Bryan Cristante        Bryan Cristante
# 6        7002                    Rafael Tolói           Rafael Tolói
# 7        7024         Jorge Luiz Frello Filho               Jorginho
# 8        7036            Gianluigi Donnarumma   Gianluigi Donnarumma
# 9        7037                 Lorenzo Insigne        Lorenzo Insigne
# 10       7038                Manuel Locatelli       Manuel Locatelli
# 11       7119                Francesco Acerbi       Francesco Acerbi
# 12       7131                Domenico Berardi       Domenico Berardi
# 13       7156                 Federico Chiesa        Federico Chiesa
# 14       7173                Leonardo Bonucci       Leonardo Bonucci
# 15       7469                Salvatore Sirigu       Salvatore Sirigu
# 16       7471                  Andrea Belotti         Andrea Belotti
# 17       7480              Alessandro Bastoni     Alessandro Bastoni
# 18       7777           Federico Bernardeschi  Federico Bernardeschi
# 19       7788                   Ciro Immobile          Ciro Immobile
# 20       8181                  Nicolò Barella         Nicolò Barella
# 21      11514             Giovanni Di Lorenzo    Giovanni Di Lorenzo
# 22      11601                  Matteo Pessina         Matteo Pessina
# 23       3333           David de Gea Quintana           David de Gea
# 24       3477      Álvaro Borja Morata Martín          Álvaro Morata
# 25       3957         César Azpilicueta Tanco      César Azpilicueta
# 26       4353                 Aymeric Laporte        Aymeric Laporte
# 27       5199      Jorge Resurrección Merodio                   Koke
# 28       5203        Sergio Busquets i Burgos        Sergio Busquets
# 29       5208  Thiago Alcântara do Nascimento       Thiago Alcântara
# 30       5211                Jordi Alba Ramos             Jordi Alba
# 31       6596             José Luis Gayà Peña              José Gayá
# 32       6655                Fabián Ruiz Peña            Fabián Ruiz
# 33       6685          Mikel Oyarzabal Ugarte        Mikel Oyarzabal
# 34       6713      Diego Javier Llorente Ríos         Diego Llorente
# 35       6748            Ferrán Torres García          Ferrán Torres
# 36       6765      Rodrigo Hernández Cascante                  Rodri
# 37       6766         Gerard Moreno Balaguero          Gerard Moreno
# 38       6840          Marcos Llorente Moreno        Marcos Llorente
# 39       6892            Pau Francisco Torres             Pau Torres
# 40       9843            Robert Lynch Sanchez         Robert Sanchez
# 41      11333             Adama Traoré Diarra           Adama Traoré
# 42      11748             Unai Simón Mendibil             Unai Simón
# 43      16532            Daniel Olmo Carvajal            Daniel Olmo
# 44      30486            Pedro González López                  Pedri
# 45      31953             Eric García Martret            Eric García
#
#     jersey_number  match_id  team_id team_name  country_id country_name  \
# 0               6   3795220      914     Italy         112        Italy
# 1              13   3795220      914     Italy         112        Italy
# 2               3   3795220      914     Italy         112        Italy
# 3              26   3795220      914     Italy         112        Italy
# 4              24   3795220      914     Italy         112        Italy
# 5              16   3795220      914     Italy         112        Italy
# 6              25   3795220      914     Italy         112        Italy
# 7               8   3795220      914     Italy         112        Italy
# 8              21   3795220      914     Italy         112        Italy
# 9              10   3795220      914     Italy         112        Italy
# 10              5   3795220      914     Italy         112        Italy
# 11             15   3795220      914     Italy         112        Italy
# 12             11   3795220      914     Italy         112        Italy
# 13             14   3795220      914     Italy         112        Italy
# 14             19   3795220      914     Italy         112        Italy
# 15              1   3795220      914     Italy         112        Italy
# 16              9   3795220      914     Italy         112        Italy
# 17             23   3795220      914     Italy         112        Italy
# 18             20   3795220      914     Italy         112        Italy
# 19             17   3795220      914     Italy         112        Italy
# 20             18   3795220      914     Italy         112        Italy
# 21              2   3795220      914     Italy         112        Italy
# 22             12   3795220      914     Italy         112        Italy
# 23              1   3795220      772     Spain         214        Spain
# 24              7   3795220      772     Spain         214        Spain
# 25              2   3795220      772     Spain         214        Spain
# 26             24   3795220      772     Spain         214        Spain
# 27              8   3795220      772     Spain         214        Spain
# 28              5   3795220      772     Spain         214        Spain
# 29             10   3795220      772     Spain         214        Spain
# 30             18   3795220      772     Spain         214        Spain
# 31             14   3795220      772     Spain         214        Spain
# 32             17   3795220      772     Spain         214        Spain
# 33             21   3795220      772     Spain         214        Spain
# 34              3   3795220      772     Spain         214        Spain
# 35             11   3795220      772     Spain         214        Spain
# 36             16   3795220      772     Spain         214        Spain
# 37              9   3795220      772     Spain         214        Spain
# 38              6   3795220      772     Spain         214        Spain
# 39              4   3795220      772     Spain         214        Spain
# 40             13   3795220      772     Spain         214        Spain
# 41             20   3795220      772     Spain         214        Spain
# 42             23   3795220      772     Spain         214        Spain
# 43             19   3795220      772     Spain         214        Spain
# 44             26   3795220      772     Spain         214        Spain
# 45             12   3795220      772     Spain         214        Spain
#
#        on    off
# 0     NaN   73.0
# 1     NaN   73.0
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6    73.0    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN   84.0
# 10   84.0    NaN
# 11    NaN    NaN
# 12   61.0    NaN
# 13    NaN  106.0
# 14    NaN    NaN
# 15    NaN    NaN
# 16   84.0    NaN
# 17    NaN    NaN
# 18  106.0    NaN
# 19    NaN   61.0
# 20    NaN   84.0
# 21    NaN    NaN
# 22   73.0    NaN
# 23    NaN    NaN
# 24   61.0    NaN
# 25    NaN   85.0
# 26    NaN    NaN
# 27    NaN   69.0
# 28    NaN  105.0
# 29  105.0    NaN
# 30    NaN    NaN
# 31    NaN    NaN
# 32    NaN    NaN
# 33    NaN   69.0
# 34    NaN    NaN
# 35    NaN   61.0
# 36   69.0    NaN
# 37   69.0    NaN
# 38   85.0    NaN
# 39  108.0    NaN
# 40    NaN    NaN
# 41    NaN    NaN
# 42    NaN    NaN
# 43    NaN    NaN
# 44    NaN    NaN
# 45    NaN  108.0

# %%
# filtering the Italy lineup
# assigning Spain as team 2

team1, team2 = lineup.team_name.unique()  # Italy (team1), Spain (team2)
team = team1
lineup_team = lineup[lineup.team_name == team].copy()

# filter the events to exclude some set pieces
set_pieces = ['Throw-in', 'Free Kick', 'Corner', 'Kick Off', 'Goal Kick']
# for the team pass map
pass_receipts = events[(events.team_name == team) & (events.type_name == 'Ball Receipt')].copy()
# for the player pass maps
passes_excl_throw = events[(events.team_name == team) & (events.type_name == 'Pass') &
                           (events.sub_type_name != 'Throw-in')].copy()

# identify how many players played and how many subs were used
# we will use this in the loop for only plotting pass maps for as
# many players who played
num_players = len(lineup_team)
num_sub = num_players - 11

#pass_receipts
#num_players
#num_sub

# %%
# add padding to the top so we can plot the titles, and raise the pitch lines
pitch = Pitch(pad_top=10, line_zorder=2)

# arrow properties for the sub on/off
green_arrow = dict(arrowstyle='simple, head_width=0.7',
                   connectionstyle="arc3,rad=-0.8", fc="green", ec="green")
red_arrow = dict(arrowstyle='simple, head_width=0.7',
                 connectionstyle="arc3,rad=-0.8", fc="red", ec="red")

# a fontmanager object for using a google font
fm_scada = FontManager('https://raw.githubusercontent.com/googlefonts/scada/main/fonts/ttf/'
                       'Scada-Regular.ttf')

SB_LOGO_URL = ('https://raw.githubusercontent.com/statsbomb/open-data/'
               'master/img/SB%20-%20Icon%20Lockup%20-%20Colour%20positive.png')

sb_logo = Image.open(urlopen(SB_LOGO_URL))
spain = Image.open('sp.png')
italy = Image.open('ita.png')

# %%
import warnings

# Filtering out some highlight_text warnings - the warnings aren't correct as the
# text fits inside the axes.
warnings.simplefilter("ignore", UserWarning)

# Plot the 7 * 3 grid
fig, axs = pitch.grid(nrows=6, ncols=4, figheight=30,
                      endnote_height=0.03, endnote_space=0,
                      axis=False,
                      title_height=0.08, grid_height=0.84)

# Plot the player pass maps
for idx, ax in enumerate(axs['pitch'].flat):
    # Plot the pass maps up to the total number of players
    if idx < num_players:
        # Filter the complete/incomplete passes for each player excluding throw-ins
        lineup_player = lineup_team.iloc[idx]
        player_id = lineup_player.player_id
        player_pass = passes_excl_throw[passes_excl_throw.player_id == player_id]
        complete_pass = player_pass[player_pass.outcome_name.isnull()]
        incomplete_pass = player_pass[player_pass.outcome_name.notnull()]

        # Plot the arrows
        pitch.arrows(complete_pass.x, complete_pass.y,
                     complete_pass.end_x, complete_pass.end_y,
                     color='#56ae6c', width=2, headwidth=4, headlength=6, ax=ax)
        pitch.arrows(incomplete_pass.x, incomplete_pass.y,
                     incomplete_pass.end_x, incomplete_pass.end_y,
                     color='#7065bb', width=2, headwidth=4, headlength=6, ax=ax)

        # Calculate total passes
        total_pass = len(complete_pass) + len(incomplete_pass)
        if total_pass == 0:
            total_pass = 1  # Ensure denominator is not zero

        # Build annotation string
        annotation_string = (f'{lineup_player.player_name} | '
                             f'<{len(complete_pass)}>/{total_pass} | ')
        if total_pass != 0:
            annotation_string += f'{round(100 * len(complete_pass) / total_pass, 1)}%'

        # Add annotation to the plot
        ax_text(0, -5, annotation_string, ha='left', va='center', fontsize=13,
                fontproperties=fm_scada.prop,  # using the font manager for the Google font
                highlight_textprops=[{"color": '#56ae6c'}], ax=ax)

        # Add information for substitutions on/off and arrows
        if not np.isnan(lineup_team.iloc[idx].off):
            ax.text(116, -10, str(lineup_team.iloc[idx].off.astype(int)), fontsize=20,
                    fontproperties=fm_scada.prop,
                    ha='center', va='center')
            ax.annotate('', (120, -2), (112, -2), arrowprops=red_arrow)
        if not np.isnan(lineup_team.iloc[idx].on):
            ax.text(104, -10, str(lineup_team.iloc[idx].on.astype(int)), fontsize=20,
                    fontproperties=fm_scada.prop,
                    ha='center', va='center')
            ax.annotate('', (108, -2), (100, -2), arrowprops=green_arrow)

# Plot on the last Pass Map
# (Note ax=ax as we have cycled through to the last axes in the loop)
pitch.kdeplot(x=pass_receipts.x, y=pass_receipts.y, ax=ax,
              cmap=cmr.lavender,
              levels=100,
              thresh=0, fill=True)
ax.text(0, -5, f'{team}: Pass Receipt Heatmap', ha='left', va='center',
        fontsize=20, fontproperties=fm_scada.prop)

# Remove unused axes (if any)
for ax in axs['pitch'].flat[11 + num_sub:-1]:
    ax.remove()

# Endnote text
axs['endnote'].text(0, 0.5, 'Grid format: @DymondFormation',
                    fontsize=20, fontproperties=fm_scada.prop, va='center', ha='left')

# Add image
ax_sb_logo = add_image(sb_logo, fig, left=0.701126,
                       # Set the bottom and height to align with the endnote
                       bottom=axs['endnote'].get_position().y0,
                       height=axs['endnote'].get_position().height)

# Title text
axs['title'].text(0.5, 0.65, f'{team1} Pass Maps vs {team2}', fontsize=40,
                  fontproperties=fm_scada.prop, va='center', ha='center')
SUB_TEXT = ('Player Pass Maps: exclude throw-ins only\n'
            'Team heatmap: includes all attempted pass receipts')
axs['title'].text(0.5, 0.35, SUB_TEXT, fontsize=20,
                  fontproperties=fm_scada.prop, va='center', ha='center')

# Plot logos (same height as the title_ax)
# Set the Italy flag to align with the left/bottom of the title axes
ax_italy_logo = add_image(italy, fig,
                          left=axs['title'].get_position().x0,
                          bottom=axs['title'].get_position().y0,
                          height=axs['title'].get_position().height)
# Set the Spain flag to align with the right/bottom of the title axes
ax_spain_logo = add_image(spain, fig, left=0.8521,
                          bottom=axs['title'].get_position().y0,
                          height=axs['title'].get_position().height)
# Out:
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
