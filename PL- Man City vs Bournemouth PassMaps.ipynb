# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import Pitch,Sbopen
import matplotlib.pyplot as plt

# %%
comps = sb.competitions()
comps['competition_name'].unique()
# Out:
# array(['1. Bundesliga', 'African Cup of Nations', 'Champions League',
#        'Copa del Rey', "FA Women's Super League", 'FIFA U20 World Cup',
#        'FIFA World Cup', 'Indian Super league', 'La Liga',
#        'Liga Profesional', 'Ligue 1', 'Major League Soccer',
#        'North American League', 'NWSL', 'Premier League', 'Serie A',
#        'UEFA Euro', 'UEFA Europa League', "UEFA Women's Euro",
#        "Women's World Cup"], dtype=object)

# %%
comps[comps['competition_name']=='Premier League']
# Out:
#     competition_id  season_id country_name competition_name  \
# 62               2         27      England   Premier League
# 63               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international  \
# 62               male              False                      False
# 63               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 62   2015/2016  2023-11-14T11:25:33.476498  2021-06-13T16:17:31.694
# 63   2003/2004  2023-11-14T11:20:59.843499  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 62                None  2023-11-14T11:25:33.476498
# 63                None  2023-11-14T11:20:59.843499

# %%
matches = sb.matches(competition_id=2, season_id=27)
matches[matches['home_team']=='Manchester City']
# Out:
#      match_id  match_date      kick_off               competition     season  \
# 45    3754028  2015-11-28  16:00:00.000  England - Premier League  2015/2016
# 54    3754079  2015-10-03  16:00:00.000  England - Premier League  2015/2016
# 57    3754077  2015-09-19  18:30:00.000  England - Premier League  2015/2016
# 74    3754054  2015-12-26  16:00:00.000  England - Premier League  2015/2016
# 91    3754167  2015-10-31  16:00:00.000  England - Premier League  2015/2016
# 109   3754193  2015-10-17  16:00:00.000  England - Premier League  2015/2016
# 115   3754208  2015-11-21  18:30:00.000  England - Premier League  2015/2016
# 132   3754246  2015-08-29  16:00:00.000  England - Premier League  2015/2016
# 155   3754328  2015-12-12  16:00:00.000  England - Premier League  2015/2016
# 180   3754066  2015-08-16  17:00:00.000  England - Premier League  2015/2016
# 225   3754035  2016-04-09  18:30:00.000  England - Premier League  2015/2016
# 257   3754124  2016-03-20  17:00:00.000  England - Premier League  2015/2016
# 265   3754142  2016-01-13  20:45:00.000  England - Premier League  2015/2016
# 267   3754147  2016-02-14  17:15:00.000  England - Premier League  2015/2016
# 318   3754249  2016-03-05  16:00:00.000  England - Premier League  2015/2016
# 323   3754260  2016-01-16  16:00:00.000  England - Premier League  2015/2016
# 338   3754290  2016-02-06  13:45:00.000  England - Premier League  2015/2016
# 346   3754307  2016-04-23  13:45:00.000  England - Premier League  2015/2016
# 350   3754314  2016-05-08  17:00:00.000  England - Premier League  2015/2016
#
#            home_team             away_team  home_score  away_score  \
# 45   Manchester City           Southampton           3           1
# 54   Manchester City      Newcastle United           6           1
# 57   Manchester City       West Ham United           1           2
# 74   Manchester City            Sunderland           4           1
# 91   Manchester City          Norwich City           2           1
# 109  Manchester City       AFC Bournemouth           5           1
# 115  Manchester City             Liverpool           1           4
# 132  Manchester City               Watford           2           0
# 155  Manchester City          Swansea City           2           1
# 180  Manchester City               Chelsea           3           0
# 225  Manchester City  West Bromwich Albion           2           1
# 257  Manchester City     Manchester United           0           1
# 265  Manchester City               Everton           0           0
# 267  Manchester City     Tottenham Hotspur           1           2
# 318  Manchester City           Aston Villa           4           0
# 323  Manchester City        Crystal Palace           4           0
# 338  Manchester City        Leicester City           1           3
# 346  Manchester City            Stoke City           4           0
# 350  Manchester City               Arsenal           2           2
#
#     match_status  ...         last_updated_360 match_week competition_stage  \
# 45     available  ...  2021-06-13T16:17:31.694         14    Regular Season
# 54     available  ...  2021-06-13T16:17:31.694          8    Regular Season
# 57     available  ...  2021-06-13T16:17:31.694          6    Regular Season
# 74     available  ...  2021-06-13T16:17:31.694         18    Regular Season
# 91     available  ...  2021-06-13T16:17:31.694         11    Regular Season
# 109    available  ...  2021-06-13T16:17:31.694          9    Regular Season
# 115    available  ...  2021-06-13T16:17:31.694         13    Regular Season
# 132    available  ...  2021-06-13T16:17:31.694          4    Regular Season
# 155    available  ...  2021-06-13T16:17:31.694         16    Regular Season
# 180    available  ...  2021-06-13T16:17:31.694          2    Regular Season
# 225    available  ...  2021-06-12T16:17:31.694         33    Regular Season
# 257    available  ...  2021-06-12T16:17:31.694         31    Regular Season
# 265    available  ...  2021-06-12T16:17:31.694         21    Regular Season
# 267    available  ...  2021-06-12T16:17:31.694         26    Regular Season
# 318    available  ...  2021-06-12T16:17:31.694         29    Regular Season
# 323    available  ...  2021-06-12T16:17:31.694         22    Regular Season
# 338    available  ...  2021-06-12T16:17:31.694         25    Regular Season
# 346    available  ...  2021-06-12T16:17:31.694         35    Regular Season
# 350    available  ...  2021-06-12T16:17:31.694         37    Regular Season
#
#             stadium           referee                     home_managers  \
# 45   Etihad Stadium        Roger East  Manuel Luis Pellegrini Ripamonti
# 54   Etihad Stadium      Kevin Friend  Manuel Luis Pellegrini Ripamonti
# 57   Etihad Stadium     Robert Madley  Manuel Luis Pellegrini Ripamonti
# 74   Etihad Stadium    Anthony Taylor  Manuel Luis Pellegrini Ripamonti
# 91   Etihad Stadium     Robert Madley  Manuel Luis Pellegrini Ripamonti
# 109  Etihad Stadium         Mike Dean  Manuel Luis Pellegrini Ripamonti
# 115  Etihad Stadium     Jonathan Moss  Manuel Luis Pellegrini Ripamonti
# 132  Etihad Stadium  Mark Clattenburg  Manuel Luis Pellegrini Ripamonti
# 155  Etihad Stadium     Robert Madley  Manuel Luis Pellegrini Ripamonti
# 180  Etihad Stadium   Martin Atkinson  Manuel Luis Pellegrini Ripamonti
# 225  Etihad Stadium        Mike Jones  Manuel Luis Pellegrini Ripamonti
# 257  Etihad Stadium    Michael Oliver  Manuel Luis Pellegrini Ripamonti
# 265  Etihad Stadium        Roger East  Manuel Luis Pellegrini Ripamonti
# 267  Etihad Stadium  Mark Clattenburg  Manuel Luis Pellegrini Ripamonti
# 318  Etihad Stadium         Lee Mason  Manuel Luis Pellegrini Ripamonti
# 323  Etihad Stadium     Jonathan Moss  Manuel Luis Pellegrini Ripamonti
# 338  Etihad Stadium    Anthony Taylor  Manuel Luis Pellegrini Ripamonti
# 346  Etihad Stadium     Robert Madley  Manuel Luis Pellegrini Ripamonti
# 350  Etihad Stadium    Anthony Taylor  Manuel Luis Pellegrini Ripamonti
#
#                             away_managers data_version shot_fidelity_version  \
# 45                          Ronald Koeman        1.1.0                     2
# 54                         Steve McClaren        1.1.0                     2
# 57                           Slaven Bilić        1.1.0                     2
# 74                          Sam Allardyce        1.1.0                     2
# 91                              Alex Neil        1.1.0                     2
# 109                            Eddie Howe        1.1.0                     2
# 115                          Jürgen Klopp        1.1.0                     2
# 132                Enrique Sánchez Flores        1.1.0                     2
# 155                           Alan Curtis        1.1.0                     2
# 180  José Mario Felix dos Santos Mourinho        1.1.0                     2
# 225                            Tony Pulis        1.1.0                     2
# 257                        Louis van Gaal        1.1.0                     2
# 265             Roberto Martínez Montoliú        1.1.0                     2
# 267  Mauricio Roberto Pochettino Trossero        1.1.0                     2
# 318                            Rémi Garde        1.1.0                     2
# 323                           Alan Pardew        1.1.0                     2
# 338                       Claudio Ranieri        1.1.0                     2
# 346                           Mark Hughes        1.1.0                     2
# 350                         Arsène Wenger        1.1.0                     2
#
#     xy_fidelity_version
# 45                    2
# 54                    2
# 57                    2
# 74                    2
# 91                    2
# 109                   2
# 115                   2
# 132                   2
# 155                   2
# 180                   2
# 225                   2
# 257                   2
# 265                   2
# 267                   2
# 318                   2
# 323                   2
# 338                   2
# 346                   2
# 350                   2
#
# [19 rows x 22 columns]

# %%
event = sb.events(match_id=3754193)
event
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 0      NaN                  NaN                            NaN
# 1      NaN                  NaN                            NaN
# 2      NaN                  NaN                            NaN
# 3      NaN                  NaN                            NaN
# 4      NaN                  NaN                            NaN
# ...    ...                  ...                            ...
# 3611   NaN                  NaN                            NaN
# 3612   NaN                  NaN                            NaN
# 3613   NaN                  NaN                            NaN
# 3614   NaN                  NaN                            NaN
# 3615   NaN                  NaN                            NaN
#
#      block_deflection carry_end_location clearance_aerial_won  \
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                  NaN
# 2                 NaN                NaN                  NaN
# 3                 NaN                NaN                  NaN
# 4                 NaN                NaN                  NaN
# ...               ...                ...                  ...
# 3611              NaN                NaN                  NaN
# 3612              NaN                NaN                  NaN
# 3613              NaN                NaN                  NaN
# 3614              NaN                NaN                  NaN
# 3615              NaN                NaN                  NaN
#
#      clearance_body_part clearance_head clearance_left_foot  \
# 0                    NaN            NaN                 NaN
# 1                    NaN            NaN                 NaN
# 2                    NaN            NaN                 NaN
# 3                    NaN            NaN                 NaN
# 4                    NaN            NaN                 NaN
# ...                  ...            ...                 ...
# 3611                 NaN            NaN                 NaN
# 3612                 NaN            NaN                 NaN
# 3613                 NaN            NaN                 NaN
# 3614                 NaN            NaN                 NaN
# 3615                 NaN            NaN                 NaN
#
#      clearance_right_foot  ... substitution_outcome substitution_outcome_id  \
# 0                     NaN  ...                  NaN                     NaN
# 1                     NaN  ...                  NaN                     NaN
# 2                     NaN  ...                  NaN                     NaN
# 3                     NaN  ...                  NaN                     NaN
# 4                     NaN  ...                  NaN                     NaN
# ...                   ...  ...                  ...                     ...
# 3611                  NaN  ...             Tactical                   103.0
# 3612                  NaN  ...             Tactical                   103.0
# 3613                  NaN  ...             Tactical                   103.0
# 3614                  NaN  ...                  NaN                     NaN
# 3615                  NaN  ...                  NaN                     NaN
#
#        substitution_replacement substitution_replacement_id  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 3611                Joshua King                      3346.0
# 3612  Kelechi Promise Iheanacho                      3708.0
# 3613                  Marc Pugh                      3646.0
# 3614                        NaN                         NaN
# 3615                        NaN                         NaN
#
#                                                 tactics             team  \
# 0     {'formation': 4231, 'lineup': [{'player': {'id...  Manchester City
# 1     {'formation': 4141, 'lineup': [{'player': {'id...  AFC Bournemouth
# 2                                                   NaN  AFC Bournemouth
# 3                                                   NaN  Manchester City
# 4                                                   NaN  AFC Bournemouth
# ...                                                 ...              ...
# 3611                                                NaN  AFC Bournemouth
# 3612                                                NaN  Manchester City
# 3613                                                NaN  AFC Bournemouth
# 3614                                                NaN  Manchester City
# 3615                                                NaN  Manchester City
#
#      team_id     timestamp             type under_pressure
# 0         36  00:00:00.000      Starting XI            NaN
# 1         28  00:00:00.000      Starting XI            NaN
# 2         28  00:00:00.000       Half Start            NaN
# 3         36  00:00:00.000       Half Start            NaN
# 4         28  00:00:00.000       Half Start            NaN
# ...      ...           ...              ...            ...
# 3611      28  00:28:59.710     Substitution            NaN
# 3612      36  00:31:52.897     Substitution            NaN
# 3613      28  00:32:17.327     Substitution            NaN
# 3614      36  00:06:38.768  Injury Stoppage            NaN
# 3615      36  00:41:07.339  Injury Stoppage            NaN
#
# [3616 rows x 91 columns]

# %%
parser = Sbopen()
df, related,freeze,tactics = parser.event(3754193)

# %%
df
# Out:
#                                         id  index  period        timestamp  \
# 0     1801d78d-b3b6-4717-b091-bd870e51d1ed      1       1         00:00:00
# 1     424c870d-6909-4df2-a45c-c721b21cf71d      2       1         00:00:00
# 2     8d51d5df-d2b5-4192-9807-529188b30a18      3       1         00:00:00
# 3     f89507ad-9d4f-499a-8529-26db01db5457      4       1         00:00:00
# 4     dd8ce1b5-c0f8-45e1-a01e-151494d04d98      5       1  00:00:00.219000
# ...                                    ...    ...     ...              ...
# 3611  c7d5bfe7-0328-413f-81d1-073ca80d7935   3612       2  00:47:52.109000
# 3612  b2c56c7a-2bf7-4304-84f5-48c7c8cdd10d   3613       2  00:47:58.806000
# 3613  fdc659ff-048d-4470-81fc-c95fb53337cd   3614       2  00:48:00.369000
# 3614  4baa86a3-bc58-47c6-bc82-de582da280de   3615       2  00:48:02.032000
# 3615  9a0eab40-fa26-49c3-b918-599a93804367   3616       2  00:48:02.032000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 0          0       0           1  0.000000   3754193       35  ...
# 1          0       0           1  0.000000   3754193       35  ...
# 2          0       0           1  0.000000   3754193       18  ...
# 3          0       0           1  0.000000   3754193       18  ...
# 4          0       0           2  0.847308   3754193       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 3611      92      52         200  0.000000   3754193        6  ...
# 3612      92      58         201  1.562289   3754193       30  ...
# 3613      93       0         201       NaN   3754193       42  ...
# 3614      93       2         201  0.000000   3754193       34  ...
# 3615      93       2         201  0.000000   3754193       34  ...
#
#      pass_switch  foul_committed_advantage foul_won_advantage  \
# 0            NaN                       NaN                NaN
# 1            NaN                       NaN                NaN
# 2            NaN                       NaN                NaN
# 3            NaN                       NaN                NaN
# 4            NaN                       NaN                NaN
# ...          ...                       ...                ...
# 3611         NaN                       NaN                NaN
# 3612         NaN                       NaN                NaN
# 3613         NaN                       NaN                NaN
# 3614         NaN                       NaN                NaN
# 3615         NaN                       NaN                NaN
#
#       ball_recovery_recovery_failure shot_deflected  block_deflection  \
# 0                                NaN            NaN               NaN
# 1                                NaN            NaN               NaN
# 2                                NaN            NaN               NaN
# 3                                NaN            NaN               NaN
# 4                                NaN            NaN               NaN
# ...                              ...            ...               ...
# 3611                             NaN            NaN               NaN
# 3612                             NaN            NaN               NaN
# 3613                             NaN            NaN               NaN
# 3614                             NaN            NaN               NaN
# 3615                             NaN            NaN               NaN
#
#      foul_committed_card_id foul_committed_card_name  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# ...                     ...                      ...
# 3611                    NaN                      NaN
# 3612                    NaN                      NaN
# 3613                    NaN                      NaN
# 3614                    NaN                      NaN
# 3615                    NaN                      NaN
#
#       substitution_replacement_id substitution_replacement_name
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 3611                          NaN                           NaN
# 3612                          NaN                           NaN
# 3613                          NaN                           NaN
# 3614                          NaN                           NaN
# 3615                          NaN                           NaN
#
# [3616 rows x 70 columns]

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'counterpress', 'aerial_won', 'out',
#        'off_camera', 'pass_cross', 'shot_statsbomb_xg', 'technique_id',
#        'technique_name', 'goalkeeper_position_id', 'goalkeeper_position_name',
#        'shot_first_time', 'pass_assisted_shot_id', 'pass_shot_assist',
#        'shot_one_on_one', 'end_z', 'shot_key_pass_id', 'pass_cut_back',
#        'pass_goal_assist', 'shot_open_goal', 'dribble_nutmeg',
#        'foul_won_defensive', 'pass_switch', 'foul_committed_advantage',
#        'foul_won_advantage', 'ball_recovery_recovery_failure',
#        'shot_deflected', 'block_deflection', 'foul_committed_card_id',
#        'foul_committed_card_name', 'substitution_replacement_id',
#        'substitution_replacement_name'],
#       dtype='object')

# %%
df = df[df['team_name']=='Manchester City']
df
# Out:
#                                         id  index  period        timestamp  \
# 0     1801d78d-b3b6-4717-b091-bd870e51d1ed      1       1         00:00:00
# 3     f89507ad-9d4f-499a-8529-26db01db5457      4       1         00:00:00
# 13    1934f282-26e7-4c45-b699-f4a573b44c83     13       1  00:00:07.897000
# 18    6a12bc3a-7a35-42d8-aeee-38c4c1656953     18       1  00:00:12.398000
# 20    e719d564-f9dc-4701-88f4-cf55d219e4c2     20       1  00:00:13.578000
# ...                                    ...    ...     ...              ...
# 3584  003c42ae-77d5-4c3c-9313-5f75b1a985f2   3585       2  00:46:53.839000
# 3601  b45f4ea7-a2b2-4a1a-9e28-a755c4ba1e78   3602       2  00:47:10.231000
# 3603  1c575c21-55d4-4fc0-904c-32ccf7c8edb7   3604       2  00:47:42.811000
# 3611  c7d5bfe7-0328-413f-81d1-073ca80d7935   3612       2  00:47:52.109000
# 3614  4baa86a3-bc58-47c6-bc82-de582da280de   3615       2  00:48:02.032000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 0          0       0           1  0.000000   3754193       35  ...
# 3          0       0           1  0.000000   3754193       18  ...
# 13         0       7           2  0.662206   3754193       17  ...
# 18         0      12           2  0.261195   3754193       30  ...
# 20         0      13           2  0.711503   3754193       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 3584      91      53         199  0.600690   3754193       17  ...
# 3601      92      10         199  0.000000   3754193        9  ...
# 3603      92      42         200  0.000000   3754193        9  ...
# 3611      92      52         200  0.000000   3754193        6  ...
# 3614      93       2         201  0.000000   3754193       34  ...
#
#      pass_switch  foul_committed_advantage foul_won_advantage  \
# 0            NaN                       NaN                NaN
# 3            NaN                       NaN                NaN
# 13           NaN                       NaN                NaN
# 18           NaN                       NaN                NaN
# 20           NaN                       NaN                NaN
# ...          ...                       ...                ...
# 3584         NaN                       NaN                NaN
# 3601         NaN                       NaN                NaN
# 3603         NaN                       NaN                NaN
# 3611         NaN                       NaN                NaN
# 3614         NaN                       NaN                NaN
#
#       ball_recovery_recovery_failure shot_deflected  block_deflection  \
# 0                                NaN            NaN               NaN
# 3                                NaN            NaN               NaN
# 13                               NaN            NaN               NaN
# 18                               NaN            NaN               NaN
# 20                               NaN            NaN               NaN
# ...                              ...            ...               ...
# 3584                             NaN            NaN               NaN
# 3601                             NaN            NaN               NaN
# 3603                             NaN            NaN               NaN
# 3611                             NaN            NaN               NaN
# 3614                             NaN            NaN               NaN
#
#      foul_committed_card_id foul_committed_card_name  \
# 0                       NaN                      NaN
# 3                       NaN                      NaN
# 13                      NaN                      NaN
# 18                      NaN                      NaN
# 20                      NaN                      NaN
# ...                     ...                      ...
# 3584                    NaN                      NaN
# 3601                    NaN                      NaN
# 3603                    NaN                      NaN
# 3611                    NaN                      NaN
# 3614                    NaN                      NaN
#
#       substitution_replacement_id substitution_replacement_name
# 0                             NaN                           NaN
# 3                             NaN                           NaN
# 13                            NaN                           NaN
# 18                            NaN                           NaN
# 20                            NaN                           NaN
# ...                           ...                           ...
# 3584                          NaN                           NaN
# 3601                          NaN                           NaN
# 3603                          NaN                           NaN
# 3611                          NaN                           NaN
# 3614                          NaN                           NaN
#
# [1938 rows x 70 columns]

# %%
df['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pressure', 'Pass', 'Ball Receipt',
#        'Carry', 'Dribble', 'Clearance', 'Block', 'Goal Keeper', 'Duel',
#        'Ball Recovery', 'Dispossessed', 'Shot', 'Miscontrol',
#        'Foul Committed', 'Foul Won', '50/50', 'Half End', 'Substitution',
#        'Injury Stoppage', 'Dribbled Past'], dtype=object)

# %%
passes = df[df['type_name']=='Pass']
passes
# Out:
#                                         id  index  period        timestamp  \
# 18    6a12bc3a-7a35-42d8-aeee-38c4c1656953     18       1  00:00:12.398000
# 20    e719d564-f9dc-4701-88f4-cf55d219e4c2     20       1  00:00:13.578000
# 54    6ae12237-3f74-4c8d-97f8-e35eed3f216d     54       1  00:00:41.392000
# 56    b1c9723c-08c1-44aa-b84e-c7c8dadf539a     56       1  00:00:42.151000
# 59    97f9e602-1508-4813-a397-f6c0ecb597da     59       1  00:00:44.197000
# ...                                    ...    ...     ...              ...
# 3555  371c585a-ba98-4cb6-b198-927030532ce6   3556       2  00:45:46.155000
# 3557  8328b0ca-3efa-48db-8922-8ff804f4dba4   3558       2  00:45:51.103000
# 3564  3b344e65-72f7-463c-a40f-5bc4d4089d66   3565       2  00:46:27.138000
# 3567  2e365a49-503e-44b1-992e-0977c812b74b   3568       2  00:46:29.740000
# 3570  7ee3e8e4-a760-4edd-bff9-ddfffa40927f   3571       2  00:46:32.910000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 18         0      12           2  0.261195   3754193       30  ...
# 20         0      13           2  0.711503   3754193       30  ...
# 54         0      41           3  0.758715   3754193       30  ...
# 56         0      42           3  0.852492   3754193       30  ...
# 59         0      44           3  1.133621   3754193       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 3555      90      46         196  3.305706   3754193       30  ...
# 3557      90      51         196  1.390632   3754193       30  ...
# 3564      91      27         198  1.601614   3754193       30  ...
# 3567      91      29         198  1.257680   3754193       30  ...
# 3570      91      32         198  3.045867   3754193       30  ...
#
#      pass_switch  foul_committed_advantage foul_won_advantage  \
# 18           NaN                       NaN                NaN
# 20           NaN                       NaN                NaN
# 54           NaN                       NaN                NaN
# 56           NaN                       NaN                NaN
# 59           NaN                       NaN                NaN
# ...          ...                       ...                ...
# 3555         NaN                       NaN                NaN
# 3557         NaN                       NaN                NaN
# 3564         NaN                       NaN                NaN
# 3567         NaN                       NaN                NaN
# 3570         NaN                       NaN                NaN
#
#       ball_recovery_recovery_failure shot_deflected  block_deflection  \
# 18                               NaN            NaN               NaN
# 20                               NaN            NaN               NaN
# 54                               NaN            NaN               NaN
# 56                               NaN            NaN               NaN
# 59                               NaN            NaN               NaN
# ...                              ...            ...               ...
# 3555                             NaN            NaN               NaN
# 3557                             NaN            NaN               NaN
# 3564                             NaN            NaN               NaN
# 3567                             NaN            NaN               NaN
# 3570                             NaN            NaN               NaN
#
#      foul_committed_card_id foul_committed_card_name  \
# 18                      NaN                      NaN
# 20                      NaN                      NaN
# 54                      NaN                      NaN
# 56                      NaN                      NaN
# 59                      NaN                      NaN
# ...                     ...                      ...
# 3555                    NaN                      NaN
# 3557                    NaN                      NaN
# 3564                    NaN                      NaN
# 3567                    NaN                      NaN
# 3570                    NaN                      NaN
#
#       substitution_replacement_id substitution_replacement_name
# 18                            NaN                           NaN
# 20                            NaN                           NaN
# 54                            NaN                           NaN
# 56                            NaN                           NaN
# 59                            NaN                           NaN
# ...                           ...                           ...
# 3555                          NaN                           NaN
# 3557                          NaN                           NaN
# 3564                          NaN                           NaN
# 3567                          NaN                           NaN
# 3570                          NaN                           NaN
#
# [610 rows x 70 columns]

# %%
passes = passes[['id','minute','player_id','player_name','x','y','end_x', 'end_y','pass_recipient_id','pass_recipient_name','outcome_id','outcome_name']]

# %%
passes
# Out:
#                                         id  minute  player_id  \
# 18    6a12bc3a-7a35-42d8-aeee-38c4c1656953       0     3090.0
# 20    e719d564-f9dc-4701-88f4-cf55d219e4c2       0     3087.0
# 54    6ae12237-3f74-4c8d-97f8-e35eed3f216d       0     3054.0
# 56    b1c9723c-08c1-44aa-b84e-c7c8dadf539a       0     3389.0
# 59    97f9e602-1508-4813-a397-f6c0ecb597da       0     3087.0
# ...                                    ...     ...        ...
# 3555  371c585a-ba98-4cb6-b198-927030532ce6      90     3291.0
# 3557  8328b0ca-3efa-48db-8922-8ff804f4dba4      90     3598.0
# 3564  3b344e65-72f7-463c-a40f-5bc4d4089d66      91     3708.0
# 3567  2e365a49-503e-44b1-992e-0977c812b74b      91     3090.0
# 3570  7ee3e8e4-a760-4edd-bff9-ddfffa40927f      91     6821.0
#
#                     player_name     x     y  end_x  end_y  pass_recipient_id  \
# 18      Nicolás Hernán Otamendi  40.7  56.2   43.1   55.1                NaN
# 20          Gnégnéri Yaya Touré  55.2  57.3   63.0   63.0                NaN
# 54           Fernando Luiz Rosa  26.9  18.2   22.0   21.2             3389.0
# 56             Eliaquim Mangala  22.0  21.4   28.2   23.1             3087.0
# 59          Gnégnéri Yaya Touré  32.4  25.3   42.0   43.8             6821.0
# ...                         ...   ...   ...    ...    ...                ...
# 3555                   Joe Hart   7.0  44.1   72.8   18.9             3598.0
# 3557     Wilfried Guemiand Bony  81.5  20.1   98.3   24.9             3708.0
# 3564  Kelechi Promise Iheanacho  46.0  18.5   31.5   40.6             3090.0
# 3567    Nicolás Hernán Otamendi  36.3  44.1   58.4   57.6             6821.0
# 3570       Jesús Navas González  70.2  58.6  112.7   38.4             3598.0
#
#             pass_recipient_name  outcome_id  outcome_name
# 18                          NaN         9.0    Incomplete
# 20                          NaN         9.0    Incomplete
# 54             Eliaquim Mangala         NaN           NaN
# 56          Gnégnéri Yaya Touré         NaN           NaN
# 59         Jesús Navas González         NaN           NaN
# ...                         ...         ...           ...
# 3555     Wilfried Guemiand Bony         NaN           NaN
# 3557  Kelechi Promise Iheanacho        76.0  Pass Offside
# 3564    Nicolás Hernán Otamendi         NaN           NaN
# 3567       Jesús Navas González         NaN           NaN
# 3570     Wilfried Guemiand Bony         9.0    Incomplete
#
# [610 rows x 12 columns]

# %%
passes['outcome_name'].unique()
# Out:
# array(['Incomplete', nan, 'Out', 'Pass Offside', 'Unknown'], dtype=object)

# %%
successful = passes[passes['outcome_name'].isnull()]
successful
# Out:
#                                         id  minute  player_id  \
# 54    6ae12237-3f74-4c8d-97f8-e35eed3f216d       0     3054.0
# 56    b1c9723c-08c1-44aa-b84e-c7c8dadf539a       0     3389.0
# 59    97f9e602-1508-4813-a397-f6c0ecb597da       0     3087.0
# 63    16b1d3f2-b35b-47dc-869d-82082a8cbfd4       0     6821.0
# 67    f10e3c5c-c8fb-4e51-b6f7-cf624fc1e4d0       0     3089.0
# ...                                    ...     ...        ...
# 3515  8f69feba-7d5a-4838-90d4-7d32187c42f7      88     3054.0
# 3518  fe7d845f-b506-442a-a206-14814434597a      88     6821.0
# 3555  371c585a-ba98-4cb6-b198-927030532ce6      90     3291.0
# 3564  3b344e65-72f7-463c-a40f-5bc4d4089d66      91     3708.0
# 3567  2e365a49-503e-44b1-992e-0977c812b74b      91     3090.0
#
#                     player_name      x     y  end_x  end_y  pass_recipient_id  \
# 54           Fernando Luiz Rosa   26.9  18.2   22.0   21.2             3389.0
# 56             Eliaquim Mangala   22.0  21.4   28.2   23.1             3087.0
# 59          Gnégnéri Yaya Touré   32.4  25.3   42.0   43.8             6821.0
# 63         Jesús Navas González   50.3  21.4   50.8    2.2             3089.0
# 67              Kevin De Bruyne   50.0   5.5   45.1   15.7             3087.0
# ...                         ...    ...   ...    ...    ...                ...
# 3515         Fernando Luiz Rosa   36.3  62.8   46.0   74.8             6821.0
# 3518       Jesús Navas González  109.1  63.1  110.8   45.5             3598.0
# 3555                   Joe Hart    7.0  44.1   72.8   18.9             3598.0
# 3564  Kelechi Promise Iheanacho   46.0  18.5   31.5   40.6             3090.0
# 3567    Nicolás Hernán Otamendi   36.3  44.1   58.4   57.6             6821.0
#
#           pass_recipient_name  outcome_id outcome_name
# 54           Eliaquim Mangala         NaN          NaN
# 56        Gnégnéri Yaya Touré         NaN          NaN
# 59       Jesús Navas González         NaN          NaN
# 63            Kevin De Bruyne         NaN          NaN
# 67        Gnégnéri Yaya Touré         NaN          NaN
# ...                       ...         ...          ...
# 3515     Jesús Navas González         NaN          NaN
# 3518   Wilfried Guemiand Bony         NaN          NaN
# 3555   Wilfried Guemiand Bony         NaN          NaN
# 3564  Nicolás Hernán Otamendi         NaN          NaN
# 3567     Jesús Navas González         NaN          NaN
#
# [500 rows x 12 columns]

# %%
subs = df[df['type_name']=='Substitution']
subs = subs['minute']
firstSub= subs.min()
firstSub
# Out:
# 45

# %%
successful = successful[successful['minute']<firstSub]
successful
# Out:
#                                         id  minute  player_id  \
# 54    6ae12237-3f74-4c8d-97f8-e35eed3f216d       0     3054.0
# 56    b1c9723c-08c1-44aa-b84e-c7c8dadf539a       0     3389.0
# 59    97f9e602-1508-4813-a397-f6c0ecb597da       0     3087.0
# 63    16b1d3f2-b35b-47dc-869d-82082a8cbfd4       0     6821.0
# 67    f10e3c5c-c8fb-4e51-b6f7-cf624fc1e4d0       0     3089.0
# ...                                    ...     ...        ...
# 1720  54018851-89a8-459e-93bf-af9068c4208e      44     3089.0
# 1729  c2a63c61-8215-46c2-95dc-20e3b5987910      44     6821.0
# 1732  32360905-8849-4282-b0bd-2447b64d35eb      44     3052.0
# 1751  d74acdfd-aab5-4af4-8e6d-e9a6681d81fd      44     6821.0
# 1754  a951b2c4-3c25-4e9f-91ca-edd5537d12b0      44     3233.0
#
#                       player_name      x     y  end_x  end_y  \
# 54             Fernando Luiz Rosa   26.9  18.2   22.0   21.2
# 56               Eliaquim Mangala   22.0  21.4   28.2   23.1
# 59            Gnégnéri Yaya Touré   32.4  25.3   42.0   43.8
# 63           Jesús Navas González   50.3  21.4   50.8    2.2
# 67                Kevin De Bruyne   50.0   5.5   45.1   15.7
# ...                           ...    ...   ...    ...    ...
# 1720              Kevin De Bruyne   73.4   6.0   69.3   17.3
# 1729         Jesús Navas González   98.2  72.6  109.0   72.7
# 1732  Pablo Javier Zabaleta Girod  109.5  72.1   94.4   74.8
# 1751         Jesús Navas González   87.0  60.8   89.5   44.1
# 1754              Raheem Sterling   99.1  47.0   96.6   23.1
#
#       pass_recipient_id          pass_recipient_name  outcome_id outcome_name
# 54               3389.0             Eliaquim Mangala         NaN          NaN
# 56               3087.0          Gnégnéri Yaya Touré         NaN          NaN
# 59               6821.0         Jesús Navas González         NaN          NaN
# 63               3089.0              Kevin De Bruyne         NaN          NaN
# 67               3087.0          Gnégnéri Yaya Touré         NaN          NaN
# ...                 ...                          ...         ...          ...
# 1720             3087.0          Gnégnéri Yaya Touré         NaN          NaN
# 1729             3052.0  Pablo Javier Zabaleta Girod         NaN          NaN
# 1732             6821.0         Jesús Navas González         NaN          NaN
# 1751             3233.0              Raheem Sterling         NaN          NaN
# 1754             3089.0              Kevin De Bruyne         NaN          NaN
#
# [245 rows x 12 columns]

# %%
df_lineup = parser.lineup(3754193)
jersey_data =df_lineup[['player_id','jersey_number']]
jersey_data
# Out:
#     player_id  jersey_number
# 0        3049             30
# 1        3085             27
# 2        3341              3
# 3        3343              4
# 4        3344              6
# 5        3345             11
# 6        3346             17
# 7        3608              2
# 8        3646              7
# 9        4738             24
# 10       4822             38
# 11       6409             15
# 12       9911             33
# 13      13248             32
# 14      13573             18
# 15      24888             23
# 16      29382             16
# 17      40218             25
# 18       3052              5
# 19       3054             25
# 20       3087             42
# 21       3089             17
# 22       3090             30
# 23       3101              4
# 24       3233              7
# 25       3291              1
# 26       3389             20
# 27       3598             14
# 28       3659             13
# 29       3708             72
# 30       6821             15
# 31       7110              3
# 32      11295             27
# 33      16003              6
# 34      19288             26
# 35      20253              8

# %%
successful = pd.merge(successful,jersey_data,on='player_id')
successful.rename(columns={'jersey_number':'passer'},inplace=True)
successful
# Out:
#                                        id  minute  player_id  \
# 0    6ae12237-3f74-4c8d-97f8-e35eed3f216d       0     3054.0
# 1    7a77bc20-5b85-4b7d-8a5a-57c833e69734       1     3054.0
# 2    7dc09490-82a8-464a-ba97-d7d17a0ab680       1     3054.0
# 3    4ca59e57-e1b5-4670-a5c5-fd814ce10bae       6     3054.0
# 4    5675b899-3cee-47dd-91aa-f460b56a05e6       6     3054.0
# ..                                    ...     ...        ...
# 240  c3f6cc0d-7203-4f65-a36f-c72a20bc523f      34     3233.0
# 241  f435d120-b032-490b-938f-1d306cff78d9      36     3233.0
# 242  39208309-acd5-4657-864e-3bb575b959b2      43     3233.0
# 243  034dd2f8-2aa6-45c8-8363-5e6732c3a971      43     3233.0
# 244  a951b2c4-3c25-4e9f-91ca-edd5537d12b0      44     3233.0
#
#             player_name     x     y  end_x  end_y  pass_recipient_id  \
# 0    Fernando Luiz Rosa  26.9  18.2   22.0   21.2             3389.0
# 1    Fernando Luiz Rosa  68.0  51.8   66.8   35.9             3087.0
# 2    Fernando Luiz Rosa  69.8  56.8   68.2   47.9             3087.0
# 3    Fernando Luiz Rosa  78.9  46.0   86.7   33.4             3233.0
# 4    Fernando Luiz Rosa  81.7  20.9   69.0   37.2             3090.0
# ..                  ...   ...   ...    ...    ...                ...
# 240     Raheem Sterling  97.4  12.3   92.6   25.8             3087.0
# 241     Raheem Sterling  89.8  35.1   83.5   45.6             3054.0
# 242     Raheem Sterling  82.1  14.6   78.0    8.0             3089.0
# 243     Raheem Sterling  84.6  11.3   76.3    6.6             3054.0
# 244     Raheem Sterling  99.1  47.0   96.6   23.1             3089.0
#
#          pass_recipient_name  outcome_id outcome_name  passer
# 0           Eliaquim Mangala         NaN          NaN      25
# 1        Gnégnéri Yaya Touré         NaN          NaN      25
# 2        Gnégnéri Yaya Touré         NaN          NaN      25
# 3            Raheem Sterling         NaN          NaN      25
# 4    Nicolás Hernán Otamendi         NaN          NaN      25
# ..                       ...         ...          ...     ...
# 240      Gnégnéri Yaya Touré         NaN          NaN       7
# 241       Fernando Luiz Rosa         NaN          NaN       7
# 242          Kevin De Bruyne         NaN          NaN       7
# 243       Fernando Luiz Rosa         NaN          NaN       7
# 244          Kevin De Bruyne         NaN          NaN       7
#
# [245 rows x 13 columns]

# %%
jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
successful = pd.merge(successful,jersey_data,on='pass_recipient_id')
successful.rename(columns={'jersey_number':'recipient'},inplace=True)
successful
# Out:
# C:\Users\sauga\AppData\Local\Temp\ipykernel_24140\289055247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
#                                        id  minute  player_id  \
# 0    6ae12237-3f74-4c8d-97f8-e35eed3f216d       0     3054.0
# 1    e2231606-706a-4b48-af8f-6142f3818106      44     3054.0
# 2    1a1c6f62-7e76-49fa-aa39-45b5cd6f4348       1     3087.0
# 3    0ed45168-52d2-4191-97c0-0f96cce30b5f       1     3087.0
# 4    26cdfda9-0834-47dd-b9a8-ba98cd65c1f6       2     3087.0
# ..                                    ...     ...        ...
# 240  5a134260-a04f-4030-8953-a67509dd5bad      20     7110.0
# 241  7ef134e1-0fb1-4556-bdf8-32f5a27c7b59      43     7110.0
# 242  a4d365ff-78d4-41e8-8cfe-cae2aa9cd321       6     3052.0
# 243  f435d120-b032-490b-938f-1d306cff78d9      36     3233.0
# 244  034dd2f8-2aa6-45c8-8363-5e6732c3a971      43     3233.0
#
#                      player_name     x     y  end_x  end_y  pass_recipient_id  \
# 0             Fernando Luiz Rosa  26.9  18.2   22.0   21.2             3389.0
# 1             Fernando Luiz Rosa  71.5  56.8   55.1   48.5             3389.0
# 2            Gnégnéri Yaya Touré  63.0  37.4   59.9   27.3             3389.0
# 3            Gnégnéri Yaya Touré  55.0  26.8   47.3   17.9             3389.0
# 4            Gnégnéri Yaya Touré  51.3  21.4   50.8   13.8             3389.0
# ..                           ...   ...   ...    ...    ...                ...
# 240                 Bacary Sagna  63.5   4.4   65.1   22.9             3054.0
# 241                 Bacary Sagna  86.8   3.0   72.8    3.4             3054.0
# 242  Pablo Javier Zabaleta Girod  75.9  59.8   73.7   29.0             3054.0
# 243              Raheem Sterling  89.8  35.1   83.5   45.6             3054.0
# 244              Raheem Sterling  84.6  11.3   76.3    6.6             3054.0
#
#     pass_recipient_name  outcome_id outcome_name  passer  recipient
# 0      Eliaquim Mangala         NaN          NaN      25         20
# 1      Eliaquim Mangala         NaN          NaN      25         20
# 2      Eliaquim Mangala         NaN          NaN      42         20
# 3      Eliaquim Mangala         NaN          NaN      42         20
# 4      Eliaquim Mangala         NaN          NaN      42         20
# ..                  ...         ...          ...     ...        ...
# 240  Fernando Luiz Rosa         NaN          NaN       3         25
# 241  Fernando Luiz Rosa         NaN          NaN       3         25
# 242  Fernando Luiz Rosa         NaN          NaN       5         25
# 243  Fernando Luiz Rosa         NaN          NaN       7         25
# 244  Fernando Luiz Rosa         NaN          NaN       7         25
#
# [245 rows x 14 columns]

# %%
average_locations = successful.groupby('passer').agg({'x':['mean'],'y':['mean','count']})

# %%
average_locations.columns = ['x','y','count']
average_locations
# Out:
#                 x          y  count
# passer
# 1       10.788889  32.744444      9
# 3       54.279487   7.658974     39
# 5       65.929167  70.050000     24
# 7       82.553333  30.406667     15
# 14      69.971429  40.835714     14
# 15      78.993333  58.686667     15
# 17      69.662963  10.640741     27
# 20      43.129630  24.888889     27
# 25      68.428571  32.433333     21
# 30      47.532000  54.136000     25
# 42      60.806897  35.813793     29

# %%
pass_between = successful.groupby(['passer','recipient']).id.count().reset_index()
pass_between.rename(columns={'id':'pass_count'},inplace=True)
pass_between
# Out:
#     passer  recipient  pass_count
# 0        1          3           1
# 1        1         14           2
# 2        1         15           1
# 3        1         17           1
# 4        1         20           3
# ..     ...        ...         ...
# 77      42         15           2
# 78      42         17           2
# 79      42         20           7
# 80      42         25           2
# 81      42         30           6
#
# [82 rows x 3 columns]

# %%
pass_between = pd.merge(pass_between, average_locations,on='passer')
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count
# 0        1          3           1  10.788889  32.744444      9
# 1        1         14           2  10.788889  32.744444      9
# 2        1         15           1  10.788889  32.744444      9
# 3        1         17           1  10.788889  32.744444      9
# 4        1         20           3  10.788889  32.744444      9
# ..     ...        ...         ...        ...        ...    ...
# 77      42         15           2  60.806897  35.813793     29
# 78      42         17           2  60.806897  35.813793     29
# 79      42         20           7  60.806897  35.813793     29
# 80      42         25           2  60.806897  35.813793     29
# 81      42         30           6  60.806897  35.813793     29
#
# [82 rows x 6 columns]

# %%
average_locations=average_locations.rename_axis('recipient')
pass_between = pd.merge(pass_between, average_locations,on='recipient',suffixes=['','_end'])
pass_between
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 0        1          3           1  10.788889  32.744444      9  54.279487
# 1        5          3           1  65.929167  70.050000     24  54.279487
# 2        7          3           2  82.553333  30.406667     15  54.279487
# 3       14          3           1  69.971429  40.835714     14  54.279487
# 4       15          3           1  78.993333  58.686667     15  54.279487
# ..     ...        ...         ...        ...        ...    ...        ...
# 77      14          5           2  69.971429  40.835714     14  65.929167
# 78      15          5           3  78.993333  58.686667     15  65.929167
# 79      25          5           1  68.428571  32.433333     21  65.929167
# 80      30          5           7  47.532000  54.136000     25  65.929167
# 81      42          5           3  60.806897  35.813793     29  65.929167
#
#         y_end  count_end
# 0    7.658974         39
# 1    7.658974         39
# 2    7.658974         39
# 3    7.658974         39
# 4    7.658974         39
# ..        ...        ...
# 77  70.050000         24
# 78  70.050000         24
# 79  70.050000         24
# 80  70.050000         24
# 81  70.050000         24
#
# [82 rows x 9 columns]

# %%
pass_between = pass_between[pass_between['pass_count']>3]

# %%
pass_between.head()
# Out:
#     passer  recipient  pass_count          x          y  count      x_end  \
# 5       17          3          10  69.662963  10.640741     27  54.279487
# 6       20          3          13  43.129630  24.888889     27  54.279487
# 7       25          3           5  68.428571  32.433333     21  54.279487
# 11       5         14           4  65.929167  70.050000     24  69.971429
# 18       5         15           9  65.929167  70.050000     24  78.993333
#
#         y_end  count_end
# 5    7.658974         39
# 6    7.658974         39
# 7    7.658974         39
# 11  40.835714         14
# 18  58.686667         15

# %%
pitch = Pitch(pitch_color='green', line_color='white',
              stripe=False)  

fig,ax = pitch.draw(figsize=(8,6))

#Draw arrows and nodes
pass_lines = pitch.lines(1.2*pass_between.x, 0.8*pass_between.y,
                         1.2*pass_between.x_end, 0.8*pass_between.y_end, lw=pass_between.pass_count*0.5,
                         color='black', zorder=1, ax=ax)

nodes = pitch.scatter(1.2*average_locations.x,0.8*average_locations.y,s=20*average_locations['count'].values,color='white',edgecolors='#a6aab3',linewidth=1,ax=ax)


# Put jersey number in the nodes

for index,row in average_locations.iterrows():
    pitch.annotate(index,xy=(1.2*row.x,0.8*row.y),c='#161A30', fontweight='bold',va='center',ha='center',size=8, ax=ax)

    
ax.set_title('Manchester City vs Bournemouth',color='red',va='center',ha='center',fontsize=12,fontweight='bold',pad=20)

ax.annotate('English Premier League', xy=(0.5, 1), xytext=(0, 0),
             xycoords='axes fraction', textcoords='offset points',
             fontsize=10, color='#0E2954', va='top', ha='center')

ax.text(114, 85, '@PLPassMap', color='#0E2954', va='bottom', ha='center', fontsize=10)
plt.show()
